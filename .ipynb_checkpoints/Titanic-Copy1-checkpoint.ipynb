# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df=pd.read_csv('train.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
pd.crosstab(df['Sex'],df['Survived'])
# Out:
# Survived    0    1
# Sex
# female     81  233
# male      468  109

# %%
ax=sns.countplot(x='Sex',hue='Survived',palette='Set2',data=df)
ax.set(title="Surviving acc to Sex",xlabel='Sex',ylabel='Total')
plt.show()

# %%
 sns.factorplot(x='Embarked',y="SibSp",hue="Sex",data=df)
# Out:
# /home/omar/.local/lib/python3.8/site-packages/seaborn/categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
df.sample()
# Out:
#     PassengerId  Survived  Pclass                            Name   Sex   Age  \
# 35           36         0       1  Holverson, Mr. Alexander Oskar  male  42.0
#
#     SibSp  Parch  Ticket  Fare Cabin Embarked
# 35      1      0  113789  52.0   NaN        S

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
graph=sns.FacetGrid(df,col="Survived")
graph.map(plt.hist,"Fare",bins=20)
df.loc[df["Fare"]>400,"Fare"]=df["Fare"].median()

# %%
graph_age=sns.FacetGrid(df,col="Survived")
graph_age.map(plt.hist,"Age",bins=20)
df.loc[df["Age"]< 20,"Age"]=45

# %%
for column in df:
    print(column,":",df[column].isnull().sum())
# Out:
# PassengerId : 0
# Survived : 0
# Pclass : 0
# Name : 0
# Sex : 0
# Age : 177
# SibSp : 0
# Parch : 0
# Ticket : 0
# Fare : 0
# Cabin : 687
# Embarked : 2

# %%
df["Age"].fillna(df["Age"].median(),inplace=True)

# %%
print(df["Embarked"].value_counts())
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
df["Embarked"].fillna("S", inplace=True)

# %%
del df["Cabin"]

# %%
df['Name'].sample(20)
# Out:
# 88                            Fortune, Miss. Mabel Helen
# 787                            Rice, Master. George Hugh
# 558               Taussig, Mrs. Emil (Tillie Mandelbaum)
# 267                             Persson, Mr. Ernst Ulrik
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 160                             Cribb, Mr. John Hatfield
# 283                           Dorking, Mr. Edward Arthur
# 363                                      Asim, Mr. Adola
# 571        Appleton, Mrs. Edward Dale (Charlotte Lamson)
# 827                                Mallet, Master. Andre
# 170                            Van der hoef, Mr. Wyckoff
# 245                          Minahan, Dr. William Edward
# 730                        Allen, Miss. Elisabeth Walton
# 116                                 Connors, Mr. Patrick
# 184                  Kink-Heilmann, Miss. Luise Gretchen
# 811                                    Lester, Mr. James
# 804                              Hedman, Mr. Oskar Arvid
# 481                     Frost, Mr. Anthony Wood "Archie"
# 161    Watt, Mrs. James (Elizabeth "Bessie" Inglis Mi...
# 447                          Seward, Mr. Frederic Kimber
# Name: Name, dtype: object

# %%
def get_title(name):
    if '.' in name:
        return name.split(',')[1].split('.')[0].strip()
    else:
        return "Missing title"

# %%
titles=set([x for x in df.Name.map(lambda x : get_title(x))])
print(titles)
# Out:
# {'Don', 'Mrs', 'Major', 'Lady', 'Jonkheer', 'Sir', 'Col', 'Miss', 'Rev', 'Capt', 'Mr', 'Mme', 'Mlle', 'the Countess', 'Dr', 'Master', 'Ms'}

# %%
def shorter_titles(x):
    titles=x['Titles']
    if titles in ['Capt','Major','Col']:
        return "Officer"
    elif titles in ["Don",'Jonkheer','the Countess','Master']:
        return "Royalty"
    elif titles in ['Mrs','Lady','Sir','Miss','Mr', 'Ms','Mlle','Mme']:
        return "Common Citizen"
    else:
        return titles

# %%
df["Titles"]=df.Name.map(lambda x : get_title(x))
df["Titles"]=df.apply(shorter_titles,axis=1)

# %%
print(df.Titles.value_counts())
# Out:
# Common Citizen    830
# Royalty            43
# Dr                  7
# Rev                 6
# Officer             5
# Name: Titles, dtype: int64

# %%
df.drop("Name",axis=1,inplace=True)

# %%
df.sample(20)
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch  \
# 728          729         0       2    male  25.0      1      0
# 846          847         0       3    male  37.0      8      2
# 849          850         1       1  female  37.0      1      0
# 565          566         0       3    male  24.0      2      0
# 210          211         0       3    male  24.0      0      0
# 128          129         1       3  female  37.0      1      1
# 497          498         0       3    male  37.0      0      0
# 640          641         0       3    male  20.0      0      0
# 2              3         1       3  female  26.0      0      0
# 879          880         1       1  female  56.0      0      1
# 36            37         1       3    male  37.0      0      0
# 494          495         0       3    male  21.0      0      0
# 413          414         0       2    male  37.0      0      0
# 821          822         1       3    male  27.0      0      0
# 611          612         0       3    male  37.0      0      0
# 267          268         1       3    male  25.0      1      0
# 21            22         1       2    male  34.0      0      0
# 30            31         0       1    male  40.0      0      0
# 3              4         1       1  female  35.0      1      0
# 404          405         0       3  female  20.0      0      0
#
#                  Ticket     Fare Embarked          Titles
# 728              236853  26.0000        S  Common Citizen
# 846            CA. 2343  69.5500        S  Common Citizen
# 849               17453  89.1042        C  Common Citizen
# 565           A/4 48871  24.1500        S  Common Citizen
# 210  SOTON/O.Q. 3101311   7.0500        S  Common Citizen
# 128                2668  22.3583        C  Common Citizen
# 497           C.A. 6212  15.1000        S  Common Citizen
# 640              350050   7.8542        S  Common Citizen
# 2      STON/O2. 3101282   7.9250        S  Common Citizen
# 879               11767  83.1583        C  Common Citizen
# 36                 2677   7.2292        C  Common Citizen
# 494           A/4 45380   8.0500        S  Common Citizen
# 413              239853   0.0000        S  Common Citizen
# 821              315098   8.6625        S  Common Citizen
# 611  SOTON/O.Q. 3101305   7.0500        S  Common Citizen
# 267              347083   7.7750        S  Common Citizen
# 21               248698  13.0000        S  Common Citizen
# 30             PC 17601  27.7208        C         Royalty
# 3                113803  53.1000        S  Common Citizen
# 404              315096   8.6625        S  Common Citizen
